# %% [markdown]
# - Datasets: TOTF, LOBSTER
# - Scalers: MinMax, Box-Cox
# - Models: Transformer+OCSVM, PRAE, PNN

# %%
import os
import torch
import joblib
import json
import pandas as pd
import numpy as np

import sys
sys.path.append("..")

from PDMM import preprocessing as prep
from PDMM import  machine_learning as ml
from PDMM import visualization as viz
from PDMM.pipeline import AnomalyDetectionPipeline, sequential_training_pipeline

os.makedirs('models', exist_ok=True)

# %%
# Configuration
DATASETS = {
    'TOTF': {
        'path': 'data/TOTF.PA-book/2015-01-02-TOTF.PA-book.csv.gz',
        'type': 'standard_csv'
    },

    'LOBSTER': {
        'orderbook': 'data/LOBSTER/AMZN_2012-06-21_34200000_57600000_orderbook_10.csv',
        'message': 'data/LOBSTER/AMZN_2012-06-21_34200000_57600000_message_10.csv',
        'type': 'lobster'
    }
}
SCALERS = ['minmax', 'box-cox']
MODELS = ['transformer_ocsvm', 'prae', 'pnn']

# Hyperparameters
SEQ_LENGTH = 25
BATCH_SIZE = 128
EPOCHS = 50
HIDDEN_DIM = 64
LR = 1e-3
PATIENCE = 5
TRAIN_RATIO = 0.7
VAL_RATIO = 0.15

# %%
# Load Data
for dataset_name, data_config in DATASETS.items():
    print(f"PROCESSING DATASET: {dataset_name}")

    pipeline = AnomalyDetectionPipeline(seq_length=SEQ_LENGTH, batch_size=BATCH_SIZE)

    try:
        # Load Data
        if data_config['type'] == 'lobster':
            df = prep.load_lobster_data(
                orderbook_path=data_config['orderbook'], 
                message_path=data_config['message'], 
                levels=10
            )
            pipeline.raw_df = df
        
        else:
            pipeline.load_data(data_config['path'])

        print(f"Loaded {len(pipeline.raw_df)} rows.")

        # Engineer Features
        pipeline.engineer_features(feature_sets=['base', 'tao', 'hawkes', 'poutre', 'ofi'])
        master_features_df = pipeline.processed_df.copy()

        for scaler_type in SCALERS:
            if dataset_name == 'TOTF' and scaler_type == 'minmax':
                continue


            
            print(f"Applying Scaler: {scaler_type}")

            pipeline.processed_df = master_features_df.copy()
            pipeline.feature_names = pipeline.processed_df.columns.tolist()

            # Scale Features
            pipeline.scale_and_sequence(method=scaler_type, train_ratio=TRAIN_RATIO, val_ratio=VAL_RATIO)

            # Train Models
            for model_type in MODELS:
                print(f"Training Model: {model_type}")

                # Train Model
                pipeline.train_model(
                    model_type=model_type, 
                    epochs=EPOCHS, 
                    lr=LR,
                    hidden_dim=HIDDEN_DIM,
                    patience=PATIENCE
                )

                # Save Artifacts
                base_filename = f"models/{dataset_name}_{scaler_type}_{model_type}"
                
                # Save Model Architecture
                config = {
                    'dataset': dataset_name,
                    'model_type': model_type,
                    'scaler_type': scaler_type,
                    'input_dim': pipeline.X_train.shape[2],
                    'seq_length': SEQ_LENGTH,
                    'hidden_dim': HIDDEN_DIM,
                    'batch_size': BATCH_SIZE,
                    'epochs': EPOCHS,
                    'learning_rate': LR,
                    'feature_names': pipeline.feature_names,
                    'train_samples': len(pipeline.X_train)
                }
                with open(f"{base_filename}_config.json", 'w') as f:
                    json.dump(config, f, indent=4)

                # Save Neural Network Weights
                torch.save(pipeline.model.state_dict(), f"{base_filename}_weights.pth")

                # Save Scaler
                joblib.dump(pipeline.scaler, f"{base_filename}_scaler.pkl")

                # Handle OC-SVM
                if model_type == 'transformer_ocsvm' and pipeline.detector is not None:
                        joblib.dump(pipeline.detector, f"{base_filename}_ocsvm_detector.pkl")
                        joblib.dump(pipeline.latent_scaler, f"{base_filename}_latent_scaler.pkl")

                print(f"Saved artifacts to {base_filename}")

    except FileNotFoundError as e:
        print(f"File not found for {dataset_name}: {e}")
        continue

    except Exception as e:
        print(f"Unexpected error processing {dataset_name}: {e}")
# Out:
# PROCESSING DATASET: TOTF
# Pipeline initialized on device: cuda
# Loading data from data/TOTF.PA-book/2015-01-02-TOTF.PA-book.csv.gz...
# Successfully loaded 640429 rows.
# Loaded 640429 rows.
# Engineering features: ['base', 'tao', 'hawkes', 'poutre', 'ofi']...
# Feature Engineering complete. Total features: 130
# Applying Scaler: box-cox
# Preprocessing with method: box-cox...
# Dropping 2 constant/zero-variance features: ['ask_sweep_cost', 'ask-volume-10']
# Data split: Train 448300, Val 96064, Test 96065
# Training Model: transformer_ocsvm
# Initializing Transformer Autoencoder...
# Training Autoencoder (Max Epochs=50)...
# Epoch 1/50 - Train Loss: 0.233387 | Val Loss: 0.118255
# Validation loss decreased (inf --> 0.118255).  Saving model ...
# Epoch 2/50 - Train Loss: 0.098460 | Val Loss: 0.078406
# Validation loss decreased (0.118255 --> 0.078406).  Saving model ...
# Epoch 3/50 - Train Loss: 0.081290 | Val Loss: 0.069582
# Validation loss decreased (0.078406 --> 0.069582).  Saving model ...
# Epoch 4/50 - Train Loss: 0.074628 | Val Loss: 0.066461
# Validation loss decreased (0.069582 --> 0.066461).  Saving model ...
# Epoch 5/50 - Train Loss: 0.070761 | Val Loss: 0.065494
# Validation loss decreased (0.066461 --> 0.065494).  Saving model ...
# Epoch 6/50 - Train Loss: 0.068006 | Val Loss: 0.064139
# Validation loss decreased (0.065494 --> 0.064139).  Saving model ...
# Epoch 7/50 - Train Loss: 0.066201 | Val Loss: 0.062855
# Validation loss decreased (0.064139 --> 0.062855).  Saving model ...
# Epoch 8/50 - Train Loss: 0.065251 | Val Loss: 0.063752
# EarlyStopping counter: 1 out of 5
# Epoch 9/50 - Train Loss: 0.064552 | Val Loss: 0.061056
# Validation loss decreased (0.062855 --> 0.061056).  Saving model ...
# Epoch 10/50 - Train Loss: 0.064227 | Val Loss: 0.062566
# EarlyStopping counter: 1 out of 5
# Epoch 11/50 - Train Loss: 0.061329 | Val Loss: 0.060047
# Validation loss decreased (0.061056 --> 0.060047).  Saving model ...
# Epoch 12/50 - Train Loss: 0.060047 | Val Loss: 0.061261
# EarlyStopping counter: 1 out of 5
# Epoch 13/50 - Train Loss: 0.058256 | Val Loss: 0.057668
# Validation loss decreased (0.060047 --> 0.057668).  Saving model ...
# Epoch 14/50 - Train Loss: 0.056310 | Val Loss: 0.055316
# Validation loss decreased (0.057668 --> 0.055316).  Saving model ...
# Epoch 15/50 - Train Loss: 0.055032 | Val Loss: 0.055876
# EarlyStopping counter: 1 out of 5
# Epoch 16/50 - Train Loss: 0.054684 | Val Loss: 0.056382
# EarlyStopping counter: 2 out of 5
# Epoch 17/50 - Train Loss: 0.054367 | Val Loss: 0.054999
# Validation loss decreased (0.055316 --> 0.054999).  Saving model ...
# Epoch 18/50 - Train Loss: 0.053952 | Val Loss: 0.053674
# Validation loss decreased (0.054999 --> 0.053674).  Saving model ...
# Epoch 19/50 - Train Loss: 0.053520 | Val Loss: 0.054947
# EarlyStopping counter: 1 out of 5
# Epoch 20/50 - Train Loss: 0.053547 | Val Loss: 0.054628
# EarlyStopping counter: 2 out of 5
# Epoch 21/50 - Train Loss: 0.052857 | Val Loss: 0.053635
# Validation loss decreased (0.053674 --> 0.053635).  Saving model ...
# Epoch 22/50 - Train Loss: 0.052699 | Val Loss: 0.055002
# EarlyStopping counter: 1 out of 5
# Epoch 23/50 - Train Loss: 0.052892 | Val Loss: 0.052812
# Validation loss decreased (0.053635 --> 0.052812).  Saving model ...
# Epoch 24/50 - Train Loss: 0.052355 | Val Loss: 0.053948
# EarlyStopping counter: 1 out of 5
# Epoch 25/50 - Train Loss: 0.052568 | Val Loss: 0.052973
# EarlyStopping counter: 2 out of 5
# Epoch 26/50 - Train Loss: 0.051911 | Val Loss: 0.054684
# EarlyStopping counter: 3 out of 5
# Epoch 27/50 - Train Loss: 0.051723 | Val Loss: 0.052447
# Validation loss decreased (0.052812 --> 0.052447).  Saving model ...
# Epoch 28/50 - Train Loss: 0.051635 | Val Loss: 0.055689
# EarlyStopping counter: 1 out of 5
# Epoch 29/50 - Train Loss: 0.051842 | Val Loss: 0.053883
# EarlyStopping counter: 2 out of 5
# Epoch 30/50 - Train Loss: 0.051342 | Val Loss: 0.053412
# EarlyStopping counter: 3 out of 5
# Epoch 31/50 - Train Loss: 0.050973 | Val Loss: 0.051112
# Validation loss decreased (0.052447 --> 0.051112).  Saving model ...
# Epoch 32/50 - Train Loss: 0.050872 | Val Loss: 0.053327
# EarlyStopping counter: 1 out of 5
# Epoch 33/50 - Train Loss: 0.050785 | Val Loss: 0.051056
# Validation loss decreased (0.051112 --> 0.051056).  Saving model ...
# Epoch 34/50 - Train Loss: 0.050463 | Val Loss: 0.052083
# EarlyStopping counter: 1 out of 5
# Epoch 35/50 - Train Loss: 0.050516 | Val Loss: 0.053935
# EarlyStopping counter: 2 out of 5
# Epoch 36/50 - Train Loss: 0.050329 | Val Loss: 0.051119
# EarlyStopping counter: 3 out of 5
# Epoch 37/50 - Train Loss: 0.050315 | Val Loss: 0.051469
# EarlyStopping counter: 4 out of 5
# Epoch 38/50 - Train Loss: 0.050265 | Val Loss: 0.051058
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Extracting Latent Representations for OC-SVM...
# Training One-Class SVM (nu=0.01)...
# Saved artifacts to models/TOTF_box-cox_transformer_ocsvm
# Training Model: prae
# Initializing Probabilistic Robust Autoencoder (PRAE)...
# Auto-tuned lambda (Mean Energy Heuristic): 3.926553
# Training PRAE (lambda=3.926553, Max Epochs=50)...
# Epoch 1/50 - Train Loss: -2.763246 | Val MSE: 0.133427
# Validation loss decreased (inf --> 0.133427).  Saving model ...
# Epoch 2/50 - Train Loss: -2.907608 | Val MSE: 0.087508
# Validation loss decreased (0.133427 --> 0.087508).  Saving model ...
# Epoch 3/50 - Train Loss: -2.962663 | Val MSE: 0.072518
# Validation loss decreased (0.087508 --> 0.072518).  Saving model ...
# Epoch 4/50 - Train Loss: -3.000157 | Val MSE: 0.082912
# EarlyStopping counter: 1 out of 5
# Epoch 5/50 - Train Loss: -3.034847 | Val MSE: 0.069511
# Validation loss decreased (0.072518 --> 0.069511).  Saving model ...
# Epoch 6/50 - Train Loss: -3.064175 | Val MSE: 0.067646
# Validation loss decreased (0.069511 --> 0.067646).  Saving model ...
# Epoch 7/50 - Train Loss: -3.097212 | Val MSE: 0.067584
# Validation loss decreased (0.067646 --> 0.067584).  Saving model ...
# Epoch 8/50 - Train Loss: -3.124732 | Val MSE: 0.065942
# Validation loss decreased (0.067584 --> 0.065942).  Saving model ...
# Epoch 9/50 - Train Loss: -3.150748 | Val MSE: 0.067210
# EarlyStopping counter: 1 out of 5
# Epoch 10/50 - Train Loss: -3.177104 | Val MSE: 0.065401
# Validation loss decreased (0.065942 --> 0.065401).  Saving model ...
# Epoch 11/50 - Train Loss: -3.201251 | Val MSE: 0.066456
# EarlyStopping counter: 1 out of 5
# Epoch 12/50 - Train Loss: -3.224410 | Val MSE: 0.064700
# Validation loss decreased (0.065401 --> 0.064700).  Saving model ...
# Epoch 13/50 - Train Loss: -3.245998 | Val MSE: 0.061146
# Validation loss decreased (0.064700 --> 0.061146).  Saving model ...
# Epoch 14/50 - Train Loss: -3.269221 | Val MSE: 0.060477
# Validation loss decreased (0.061146 --> 0.060477).  Saving model ...
# Epoch 15/50 - Train Loss: -3.288063 | Val MSE: 0.062542
# EarlyStopping counter: 1 out of 5
# Epoch 16/50 - Train Loss: -3.305291 | Val MSE: 0.061557
# EarlyStopping counter: 2 out of 5
# Epoch 17/50 - Train Loss: -3.326063 | Val MSE: 0.060804
# EarlyStopping counter: 3 out of 5
# Epoch 18/50 - Train Loss: -3.344132 | Val MSE: 0.060114
# Validation loss decreased (0.060477 --> 0.060114).  Saving model ...
# Epoch 19/50 - Train Loss: -3.359935 | Val MSE: 0.061020
# EarlyStopping counter: 1 out of 5
# Epoch 20/50 - Train Loss: -3.378423 | Val MSE: 0.059624
# Validation loss decreased (0.060114 --> 0.059624).  Saving model ...
# Epoch 21/50 - Train Loss: -3.391434 | Val MSE: 0.060513
# EarlyStopping counter: 1 out of 5
# Epoch 22/50 - Train Loss: -3.409345 | Val MSE: 0.059384
# Validation loss decreased (0.059624 --> 0.059384).  Saving model ...
# Epoch 23/50 - Train Loss: -3.421389 | Val MSE: 0.059562
# EarlyStopping counter: 1 out of 5
# Epoch 24/50 - Train Loss: -3.434284 | Val MSE: 0.058903
# Validation loss decreased (0.059384 --> 0.058903).  Saving model ...
# Epoch 25/50 - Train Loss: -3.447340 | Val MSE: 0.059024
# EarlyStopping counter: 1 out of 5
# Epoch 26/50 - Train Loss: -3.464165 | Val MSE: 0.059371
# EarlyStopping counter: 2 out of 5
# Epoch 27/50 - Train Loss: -3.473962 | Val MSE: 0.060509
# EarlyStopping counter: 3 out of 5
# Epoch 28/50 - Train Loss: -3.484179 | Val MSE: 0.059615
# EarlyStopping counter: 4 out of 5
# Epoch 29/50 - Train Loss: -3.495978 | Val MSE: 0.059486
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Saved artifacts to models/TOTF_box-cox_prae
# Training Model: pnn
# Initializing Probabilistic Neural Network (PNN)...
# Training PNN (Max Epochs=50)...
# Epoch 1/50 - Train: 1.281222 | Val: 1.186094
# Validation loss decreased (inf --> 1.186094).  Saving model ...
# Epoch 2/50 - Train: 1.237183 | Val: 1.257112
# EarlyStopping counter: 1 out of 5
# Epoch 3/50 - Train: 1.404919 | Val: 1.241621
# EarlyStopping counter: 2 out of 5
# Epoch 4/50 - Train: 1.438133 | Val: 1.358036
# EarlyStopping counter: 3 out of 5
# Epoch 5/50 - Train: 1.538059 | Val: 1.640473
# EarlyStopping counter: 4 out of 5
# Epoch 6/50 - Train: 1.407687 | Val: 1.318869
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Saved artifacts to models/TOTF_box-cox_pnn
# PROCESSING DATASET: LOBSTER
# Pipeline initialized on device: cuda
# Loading LOBSTER data from data/LOBSTER/AMZN_2012-06-21_34200000_57600000_orderbook_10.csv...
# Successfully loaded 269748 LOBSTER rows.
# Loaded 269748 rows.
# Engineering features: ['base', 'tao', 'hawkes', 'poutre', 'ofi']...
# Feature Engineering complete. Total features: 129
# Applying Scaler: minmax
# Preprocessing with method: minmax...
# Dropping 12 constant/zero-variance features: ['Hawkes_L_bid_beta1000_Eta1.0', 'Hawkes_L_ask_beta1000_Eta1.0', 'Hawkes_L_ask_beta10_Eta1.0', 'Hawkes_L_ask_beta10_Eta10.0', 'Hawkes_L_bid_beta100_Eta1.0', 'Hawkes_L_ask_beta100_Eta10.0', 'Hawkes_L_bid_beta1000_Eta10.0', 'Hawkes_L_bid_beta10_Eta10.0', 'Hawkes_L_bid_beta10_Eta1.0', 'Hawkes_L_bid_beta100_Eta10.0', 'Hawkes_L_ask_beta100_Eta1.0', 'Hawkes_L_ask_beta1000_Eta10.0']
# Data split: Train 188823, Val 40462, Test 40463
# Training Model: transformer_ocsvm
# Initializing Transformer Autoencoder...
# Training Autoencoder (Max Epochs=50)...
# Epoch 1/50 - Train Loss: 0.009029 | Val Loss: 0.003654
# Validation loss decreased (inf --> 0.003654).  Saving model ...
# Epoch 2/50 - Train Loss: 0.003395 | Val Loss: 0.002645
# Validation loss decreased (0.003654 --> 0.002645).  Saving model ...
# Epoch 3/50 - Train Loss: 0.002483 | Val Loss: 0.002144
# Validation loss decreased (0.002645 --> 0.002144).  Saving model ...
# Epoch 4/50 - Train Loss: 0.001895 | Val Loss: 0.001776
# Validation loss decreased (0.002144 --> 0.001776).  Saving model ...
# Epoch 5/50 - Train Loss: 0.001455 | Val Loss: 0.001592
# Validation loss decreased (0.001776 --> 0.001592).  Saving model ...
# Epoch 6/50 - Train Loss: 0.001132 | Val Loss: 0.001229
# Validation loss decreased (0.001592 --> 0.001229).  Saving model ...
# Epoch 7/50 - Train Loss: 0.000963 | Val Loss: 0.001244
# EarlyStopping counter: 1 out of 5
# Epoch 8/50 - Train Loss: 0.000873 | Val Loss: 0.001262
# EarlyStopping counter: 2 out of 5
# Epoch 9/50 - Train Loss: 0.000814 | Val Loss: 0.001149
# Validation loss decreased (0.001229 --> 0.001149).  Saving model ...
# Epoch 10/50 - Train Loss: 0.000776 | Val Loss: 0.001249
# EarlyStopping counter: 1 out of 5
# Epoch 11/50 - Train Loss: 0.000745 | Val Loss: 0.001140
# Validation loss decreased (0.001149 --> 0.001140).  Saving model ...
# Epoch 12/50 - Train Loss: 0.000722 | Val Loss: 0.001212
# EarlyStopping counter: 1 out of 5
# Epoch 13/50 - Train Loss: 0.000703 | Val Loss: 0.001090
# Validation loss decreased (0.001140 --> 0.001090).  Saving model ...
# Epoch 14/50 - Train Loss: 0.000686 | Val Loss: 0.001148
# EarlyStopping counter: 1 out of 5
# Epoch 15/50 - Train Loss: 0.000675 | Val Loss: 0.001191
# EarlyStopping counter: 2 out of 5
# Epoch 16/50 - Train Loss: 0.000663 | Val Loss: 0.001173
# EarlyStopping counter: 3 out of 5
# Epoch 17/50 - Train Loss: 0.000654 | Val Loss: 0.001090
# EarlyStopping counter: 4 out of 5
# Epoch 18/50 - Train Loss: 0.000647 | Val Loss: 0.001144
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Extracting Latent Representations for OC-SVM...
# Training One-Class SVM (nu=0.01)...
# Saved artifacts to models/LOBSTER_minmax_transformer_ocsvm
# Training Model: prae
# Initializing Probabilistic Robust Autoencoder (PRAE)...
# Auto-tuned lambda (Mean Energy Heuristic): 0.145710
# Training PRAE (lambda=0.145710, Max Epochs=50)...
# Epoch 1/50 - Train Loss: -0.103102 | Val MSE: 0.003260
# Validation loss decreased (inf --> 0.003260).  Saving model ...
# Epoch 2/50 - Train Loss: -0.108267 | Val MSE: 0.002646
# Validation loss decreased (0.003260 --> 0.002646).  Saving model ...
# Epoch 3/50 - Train Loss: -0.109983 | Val MSE: 0.002000
# Validation loss decreased (0.002646 --> 0.002000).  Saving model ...
# Epoch 4/50 - Train Loss: -0.111585 | Val MSE: 0.001668
# Validation loss decreased (0.002000 --> 0.001668).  Saving model ...
# Epoch 5/50 - Train Loss: -0.113279 | Val MSE: 0.001493
# Validation loss decreased (0.001668 --> 0.001493).  Saving model ...
# Epoch 6/50 - Train Loss: -0.114240 | Val MSE: 0.001223
# Validation loss decreased (0.001493 --> 0.001223).  Saving model ...
# Epoch 7/50 - Train Loss: -0.115548 | Val MSE: 0.001460
# EarlyStopping counter: 1 out of 5
# Epoch 8/50 - Train Loss: -0.116452 | Val MSE: 0.001116
# Validation loss decreased (0.001223 --> 0.001116).  Saving model ...
# Epoch 9/50 - Train Loss: -0.117505 | Val MSE: 0.001203
# EarlyStopping counter: 1 out of 5
# Epoch 10/50 - Train Loss: -0.118488 | Val MSE: 0.001067
# Validation loss decreased (0.001116 --> 0.001067).  Saving model ...
# Epoch 11/50 - Train Loss: -0.119507 | Val MSE: 0.001077
# EarlyStopping counter: 1 out of 5
# Epoch 12/50 - Train Loss: -0.120080 | Val MSE: 0.001112
# EarlyStopping counter: 2 out of 5
# Epoch 13/50 - Train Loss: -0.121197 | Val MSE: 0.001106
# EarlyStopping counter: 3 out of 5
# Epoch 14/50 - Train Loss: -0.122012 | Val MSE: 0.001100
# EarlyStopping counter: 4 out of 5
# Epoch 15/50 - Train Loss: -0.122711 | Val MSE: 0.001209
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Saved artifacts to models/LOBSTER_minmax_prae
# Training Model: pnn
# Initializing Probabilistic Neural Network (PNN)...
# Training PNN (Max Epochs=50)...
# Epoch 1/50 - Train: -1.172215 | Val: -2.039819
# Validation loss decreased (inf --> -2.039819).  Saving model ...
# Epoch 2/50 - Train: -1.849165 | Val: -2.340794
# Validation loss decreased (-2.039819 --> -2.340794).  Saving model ...
# Epoch 3/50 - Train: -1.886154 | Val: -2.326454
# EarlyStopping counter: 1 out of 5
# Epoch 4/50 - Train: -1.936657 | Val: -2.402747
# Validation loss decreased (-2.340794 --> -2.402747).  Saving model ...
# Epoch 5/50 - Train: -1.964431 | Val: -2.317546
# EarlyStopping counter: 1 out of 5
# Epoch 6/50 - Train: -1.997403 | Val: -2.347195
# EarlyStopping counter: 2 out of 5
# Epoch 7/50 - Train: -1.998936 | Val: -2.386356
# EarlyStopping counter: 3 out of 5
# Epoch 8/50 - Train: -1.996292 | Val: -2.488571
# Validation loss decreased (-2.402747 --> -2.488571).  Saving model ...
# Epoch 9/50 - Train: 0.009729 | Val: 0.101542
# EarlyStopping counter: 1 out of 5
# Epoch 10/50 - Train: 0.017164 | Val: 0.195654
# EarlyStopping counter: 2 out of 5
# Epoch 11/50 - Train: -0.036183 | Val: 0.206025
# EarlyStopping counter: 3 out of 5
# Epoch 12/50 - Train: 0.136555 | Val: -0.013157
# EarlyStopping counter: 4 out of 5
# Epoch 13/50 - Train: -0.317612 | Val: -0.604572
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Saved artifacts to models/LOBSTER_minmax_pnn
# Applying Scaler: box-cox
# Preprocessing with method: box-cox...
# Dropping 12 constant/zero-variance features: ['Hawkes_L_bid_beta1000_Eta1.0', 'Hawkes_L_ask_beta1000_Eta1.0', 'Hawkes_L_ask_beta10_Eta1.0', 'Hawkes_L_ask_beta10_Eta10.0', 'Hawkes_L_bid_beta100_Eta1.0', 'Hawkes_L_ask_beta100_Eta10.0', 'Hawkes_L_bid_beta1000_Eta10.0', 'Hawkes_L_bid_beta10_Eta10.0', 'Hawkes_L_bid_beta10_Eta1.0', 'Hawkes_L_bid_beta100_Eta10.0', 'Hawkes_L_ask_beta100_Eta1.0', 'Hawkes_L_ask_beta1000_Eta10.0']
# Data split: Train 188823, Val 40462, Test 40463
# Training Model: transformer_ocsvm
# Initializing Transformer Autoencoder...
# Training Autoencoder (Max Epochs=50)...
# Epoch 1/50 - Train Loss: 0.350234 | Val Loss: 0.231923
# Validation loss decreased (inf --> 0.231923).  Saving model ...
# Epoch 2/50 - Train Loss: 0.156955 | Val Loss: 0.186018
# Validation loss decreased (0.231923 --> 0.186018).  Saving model ...
# Epoch 3/50 - Train Loss: 0.124176 | Val Loss: 0.163955
# Validation loss decreased (0.186018 --> 0.163955).  Saving model ...
# Epoch 4/50 - Train Loss: 0.110779 | Val Loss: 0.165111
# EarlyStopping counter: 1 out of 5
# Epoch 5/50 - Train Loss: 0.104302 | Val Loss: 0.161758
# Validation loss decreased (0.163955 --> 0.161758).  Saving model ...
# Epoch 6/50 - Train Loss: 0.100680 | Val Loss: 0.160399
# Validation loss decreased (0.161758 --> 0.160399).  Saving model ...
# Epoch 7/50 - Train Loss: 0.097894 | Val Loss: 0.158020
# Validation loss decreased (0.160399 --> 0.158020).  Saving model ...
# Epoch 8/50 - Train Loss: 0.095761 | Val Loss: 0.155185
# Validation loss decreased (0.158020 --> 0.155185).  Saving model ...
# Epoch 9/50 - Train Loss: 0.094162 | Val Loss: 0.158379
# EarlyStopping counter: 1 out of 5
# Epoch 10/50 - Train Loss: 0.092652 | Val Loss: 0.157463
# EarlyStopping counter: 2 out of 5
# Epoch 11/50 - Train Loss: 0.091342 | Val Loss: 0.153269
# Validation loss decreased (0.155185 --> 0.153269).  Saving model ...
# Epoch 12/50 - Train Loss: 0.090359 | Val Loss: 0.151470
# Validation loss decreased (0.153269 --> 0.151470).  Saving model ...
# Epoch 13/50 - Train Loss: 0.089533 | Val Loss: 0.152616
# EarlyStopping counter: 1 out of 5
# Epoch 14/50 - Train Loss: 0.088898 | Val Loss: 0.150538
# Validation loss decreased (0.151470 --> 0.150538).  Saving model ...
# Epoch 15/50 - Train Loss: 0.088256 | Val Loss: 0.153442
# EarlyStopping counter: 1 out of 5
# Epoch 16/50 - Train Loss: 0.087518 | Val Loss: 0.155521
# EarlyStopping counter: 2 out of 5
# Epoch 17/50 - Train Loss: 0.086584 | Val Loss: 0.153551
# EarlyStopping counter: 3 out of 5
# Epoch 18/50 - Train Loss: 0.085847 | Val Loss: 0.152827
# EarlyStopping counter: 4 out of 5
# Epoch 19/50 - Train Loss: 0.085306 | Val Loss: 0.155738
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Extracting Latent Representations for OC-SVM...
# Training One-Class SVM (nu=0.01)...
# Saved artifacts to models/LOBSTER_box-cox_transformer_ocsvm
# Training Model: prae
# Initializing Probabilistic Robust Autoencoder (PRAE)...
# Auto-tuned lambda (Mean Energy Heuristic): 1.750279
# Training PRAE (lambda=1.750279, Max Epochs=50)...
# Epoch 1/50 - Train Loss: -1.051318 | Val MSE: 0.229800
# Validation loss decreased (inf --> 0.229800).  Saving model ...
# Epoch 2/50 - Train Loss: -1.208531 | Val MSE: 0.184714
# Validation loss decreased (0.229800 --> 0.184714).  Saving model ...
# Epoch 3/50 - Train Loss: -1.247219 | Val MSE: 0.169030
# Validation loss decreased (0.184714 --> 0.169030).  Saving model ...
# Epoch 4/50 - Train Loss: -1.268796 | Val MSE: 0.162621
# Validation loss decreased (0.169030 --> 0.162621).  Saving model ...
# Epoch 5/50 - Train Loss: -1.286139 | Val MSE: 0.158637
# Validation loss decreased (0.162621 --> 0.158637).  Saving model ...
# Epoch 6/50 - Train Loss: -1.301942 | Val MSE: 0.156554
# Validation loss decreased (0.158637 --> 0.156554).  Saving model ...
# Epoch 7/50 - Train Loss: -1.318305 | Val MSE: 0.159452
# EarlyStopping counter: 1 out of 5
# Epoch 8/50 - Train Loss: -1.331597 | Val MSE: 0.159686
# EarlyStopping counter: 2 out of 5
# Epoch 9/50 - Train Loss: -1.344299 | Val MSE: 0.155929
# Validation loss decreased (0.156554 --> 0.155929).  Saving model ...
# Epoch 10/50 - Train Loss: -1.354191 | Val MSE: 0.154208
# Validation loss decreased (0.155929 --> 0.154208).  Saving model ...
# Epoch 11/50 - Train Loss: -1.367100 | Val MSE: 0.154658
# EarlyStopping counter: 1 out of 5
# Epoch 12/50 - Train Loss: -1.376793 | Val MSE: 0.155175
# EarlyStopping counter: 2 out of 5
# Epoch 13/50 - Train Loss: -1.385911 | Val MSE: 0.153835
# Validation loss decreased (0.154208 --> 0.153835).  Saving model ...
# Epoch 14/50 - Train Loss: -1.396640 | Val MSE: 0.154414
# EarlyStopping counter: 1 out of 5
# Epoch 15/50 - Train Loss: -1.406381 | Val MSE: 0.154101
# EarlyStopping counter: 2 out of 5
# Epoch 16/50 - Train Loss: -1.415613 | Val MSE: 0.155694
# EarlyStopping counter: 3 out of 5
# Epoch 17/50 - Train Loss: -1.421871 | Val MSE: 0.153640
# Validation loss decreased (0.153835 --> 0.153640).  Saving model ...
# Epoch 18/50 - Train Loss: -1.431272 | Val MSE: 0.155109
# EarlyStopping counter: 1 out of 5
# Epoch 19/50 - Train Loss: -1.440394 | Val MSE: 0.154812
# EarlyStopping counter: 2 out of 5
# Epoch 20/50 - Train Loss: -1.447026 | Val MSE: 0.153189
# Validation loss decreased (0.153640 --> 0.153189).  Saving model ...
# Epoch 21/50 - Train Loss: -1.453457 | Val MSE: 0.153979
# EarlyStopping counter: 1 out of 5
# Epoch 22/50 - Train Loss: -1.459561 | Val MSE: 0.155357
# EarlyStopping counter: 2 out of 5
# Epoch 23/50 - Train Loss: -1.465291 | Val MSE: 0.153446
# EarlyStopping counter: 3 out of 5
# Epoch 24/50 - Train Loss: -1.473192 | Val MSE: 0.153821
# EarlyStopping counter: 4 out of 5
# Epoch 25/50 - Train Loss: -1.478887 | Val MSE: 0.154006
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Saved artifacts to models/LOBSTER_box-cox_prae
# Training Model: pnn
# Initializing Probabilistic Neural Network (PNN)...
# Training PNN (Max Epochs=50)...
# Epoch 1/50 - Train: 1.359222 | Val: 1.227905
# Validation loss decreased (inf --> 1.227905).  Saving model ...
# Epoch 2/50 - Train: 1.410486 | Val: 1.479677
# EarlyStopping counter: 1 out of 5
# Epoch 3/50 - Train: 1.310100 | Val: 1.481656
# EarlyStopping counter: 2 out of 5
# Epoch 4/50 - Train: 1.366352 | Val: 1.754785
# EarlyStopping counter: 3 out of 5
# Epoch 5/50 - Train: 1.268636 | Val: 1.601381
# EarlyStopping counter: 4 out of 5
# Epoch 6/50 - Train: 1.371830 | Val: 1.407057
# EarlyStopping counter: 5 out of 5
# Early stopping triggered.
# Saved artifacts to models/LOBSTER_box-cox_pnn
